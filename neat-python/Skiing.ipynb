# %% [markdown]
# Playing ATARI-ram games using python-neat

# %% [markdown]
# # Import

# %%
import numpy as np
import gym
from gym import wrappers
from __future__ import print_function
import os
# %matplotlib inline
import neat
import visualize
os.environ['DISPLAY']=':0'

# %% [markdown]
# # Define config

# %%
fc_config_filename = 'fc.config'
game = 'Skiing-ram-v0'
num_evaluations = 3
num_cores = 10
population_size = 60

# %% [markdown]
# # Create environment

# %%
env = gym.make(game)
# Out:
# [2017-02-07 20:35:36,060] Making new env: Skiing-ram-v0

# %% [markdown]
# # Create neat-python population

# %%
# Load configuration.
config_initial = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                     neat.DefaultSpeciesSet, neat.DefaultStagnation, fc_config_filename)

config_initial.genome_config.num_inputs = env.observation_space.shape[0]
config_initial.genome_config.num_outputs = env.action_space.n
config_initial.pop_size = population_size

# %%
game_fc_config_filename = 'fc-' + game + '.config'

config_initial.save(game_fc_config_filename)

config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                     neat.DefaultSpeciesSet, neat.DefaultStagnation, game_fc_config_filename)

# Create the population, which is the top-level object for a NEAT run.
p = neat.Population(config)

# %% [markdown]
# # Add reporters

# %%
# Add a stdout reporter to show progress in the terminal.
p.add_reporter(neat.StdOutReporter())
stats = neat.StatisticsReporter()
p.add_reporter(stats)
p.add_reporter(neat.Checkpointer(5))

# %% [markdown]
# # Define fitness via game score

# %%
def transform_observation(observation):
    observation = observation / 255. * 2 - 1
    return observation

# a = argmax_a Q(s,a)
def predict_action(observation, network):
    observation = transform_observation(observation)
    output = network.activate(observation)
    action = np.argmax(output)
    return(action)

# play num_evaluations games, take mean
def evaluate_network(env, network):
    rewards = []
    i = 0
    while i < num_evaluations:
        rewards += [get_reward(env, network)]
        i += 1

    res = np.array(rewards).mean()
    return res

# play 1 game with network
def get_reward(env, network):
    observation = env.reset()
    done = False
    iteration, total_reward = 0, 0
        
    while not done:
        #env.render()
        action = predict_action(observation, network)
        observation, reward, done, info = env.step(action)
        total_reward += reward

        #if iteration % 500 == 0:
        #    print(str(iteration))

        if total_reward < -12000 or iteration >= 8000:
            break

        iteration += 1
        
    return total_reward

def evaluate_genome(genome, config):
    network = neat.nn.FeedForwardNetwork.create(genome, config)
    fitness = evaluate_network(env, network)
    return fitness
    
#print(evaluate_genome(p.species.get_species(1).members[1], config))

evaluator = neat.parallel.ParallelEvaluator(num_workers = num_cores, eval_function = evaluate_genome, timeout = None)

# %% [markdown]
# # Run evolution

# %%
# Run evolution
winner = p.run(evaluator.evaluate, 100)
# Out:
#  ****** Running generation 0 ******
#
# Population's average fitness: -11704.80000 stdev: 1029.51919
# Best fitness: -9011.00000 - size: (3, 384) - species 1 - id 22
# Species length: 1 totaling 60 individuals
# Species no improv: {1: 0}
# Average adjusted fitness: 0.412
# Spawn amounts: [60]
# Species fitness  : [0.41157710790738289]
# Mean genetic distance 1.04247239079, std dev 0.222082918557
# Total extinctions: 0
# Generation time: 216.894 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: -11305.59444 stdev: 1310.48218
# Best fitness: -8925.00000 - size: (3, 382) - species 1 - id 82
# Species length: 1 totaling 60 individuals
# Species no improv: {1: 0}
# Average adjusted fitness: 0.455
# Spawn amounts: [60]
# Species fitness  : [0.45549074921215682]
# Mean genetic distance 1.6061062895, std dev 0.178414288046
# Total extinctions: 0
# Generation time: 196.075 sec (206.485 average)
# Saving checkpoint to neat-checkpoint-1
#
#  ****** Running generation 2 ******
#
# Population's average fitness: -10231.62222 stdev: 1820.02858
# Best fitness: -8925.00000 - size: (3, 382) - species 1 - id 82
# Species length: 1 totaling 60 individuals
# Species no improv: {1: 1}
# Average adjusted fitness: 0.802
# Spawn amounts: [60]
# Species fitness  : [0.80223668499739331]
# Mean genetic distance 1.61894703523, std dev 0.248927039187
# Total extinctions: 0
# Generation time: 122.281 sec (178.417 average)
#
#  ****** Running generation 3 ******
#
# Population's average fitness: -10090.27222 stdev: 1567.54895
# Best fitness: -8833.33333 - size: (3, 382) - species 1 - id 82
# Species length: 1 totaling 60 individuals
# Species no improv: {1: 0}
# Average adjusted fitness: 0.824
# Spawn amounts: [60]
# Species fitness  : [0.82371123577995931]
# Mean genetic distance 1.28562449849, std dev 0.177227719017
# Total extinctions: 0
# Generation time: 132.232 sec (166.871 average)
#
#  ****** Running generation 4 ******
#
# Population's average fitness: -9885.02778 stdev: 1455.17678
# Best fitness: -8925.00000 - size: (3, 382) - species 1 - id 82
# Species length: 1 totaling 60 individuals
# Species no improv: {1: 1}
# Average adjusted fitness: 0.845
# Spawn amounts: [60]
# Species fitness  : [0.84454669761249357]
# Mean genetic distance 1.37533347107, std dev 0.169474859662
# Total extinctions: 0
# Generation time: 130.869 sec (159.670 average)
# Saving checkpoint to neat-checkpoint-4
#
#  ****** Running generation 5 ******
#
# Population's average fitness: -9954.58889 stdev: 1606.43892
# Best fitness: -9011.66667 - size: (4, 381) - species 1 - id 273
# Species length: 1 totaling 60 individuals
# Species no improv: {1: 2}
# Average adjusted fitness: 0.860
# Spawn amounts: [60]
# Species fitness  : [0.86017662662910066]
# Mean genetic distance 1.20387306024, std dev 0.243149929196
# Total extinctions: 0
# Generation time: 121.481 sec (153.305 average)
#
#  ****** Running generation 6 ******
#
# Population's average fitness: -10246.56111 stdev: 1839.67231
# Best fitness: -9012.33333 - size: (4, 381) - species 1 - id 273
# Species length: 1 totaling 60 individuals
# Species no improv: {1: 3}
# Average adjusted fitness: 0.837
# Spawn amounts: [60]
# Species fitness  : [0.83738764456155756]
# Mean genetic distance 1.45960372111, std dev 0.200268220027
# Total extinctions: 0
# Generation time: 127.889 sec (149.675 average)
#
#  ****** Running generation 7 ******
#
# Population's average fitness: -9646.22778 stdev: 1266.68929
# Best fitness: -9012.33333 - size: (4, 381) - species 1 - id 273
# Species length: 1 totaling 60 individuals
# Species no improv: {1: 4}
# Average adjusted fitness: 0.880
# Spawn amounts: [60]
# Species fitness  : [0.88047996145224516]
# Mean genetic distance 1.38811030117, std dev 0.365804084124
# Total extinctions: 0
# Generation time: 114.033 sec (145.219 average)
# Saving checkpoint to neat-checkpoint-7
#
#  ****** Running generation 8 ******
#
# Population's average fitness: -9464.85000 stdev: 1179.52861
# Best fitness: -9011.00000 - size: (4, 381) - species 1 - id 273
# Species length: 1 totaling 60 individuals
# Species no improv: {1: 5}
# Average adjusted fitness: 0.923
# Spawn amounts: [60]
# Species fitness  : [0.92253797576378216]
# Mean genetic distance 1.44356158979, std dev 0.177332739476
# Total extinctions: 0
# Generation time: 94.637 sec (139.599 average)
#
#  ****** Running generation 9 ******
#
# Population's average fitness: -9960.95556 stdev: 1398.94252
# Best fitness: -9012.33333 - size: (4, 369) - species 1 - id 555
# Species length: 1 totaling 60 individuals
# Species no improv: {1: 6}
# Average adjusted fitness: 0.747
# Spawn amounts: [60]
# Species fitness  : [0.74728117692330454]
# Mean genetic distance 1.58908691113, std dev 0.374047469663
# Total extinctions: 0
# Generation time: 130.226 sec (138.662 average)
#
#  ****** Running generation 10 ******
#
# Population's average fitness: -9855.28333 stdev: 1414.43661
# Best fitness: -9012.33333 - size: (4, 381) - species 1 - id 273
# Species length: 1 totaling 60 individuals
# Species no improv: {1: 7}
# Average adjusted fitness: 0.855
# Spawn amounts: [60]
# Species fitness  : [0.85510513951756162]
# Mean genetic distance 1.48245707901, std dev 0.200687921471
# Total extinctions: 0
# Generation time: 120.095 sec (128.982 average)
# Saving checkpoint to neat-checkpoint-10
#
#  ****** Running generation 11 ******
#
# Population's average fitness: -9808.67222 stdev: 1436.51850
# Best fitness: -9011.00000 - size: (4, 381) - species 1 - id 273
# Species length: 1 totaling 60 individuals
# Species no improv: {1: 8}
# Average adjusted fitness: 0.861
# Spawn amounts: [60]
# Species fitness  : [0.86063615009803329]
# Mean genetic distance 1.62394367721, std dev 0.237034167627
# Total extinctions: 0
# Generation time: 110.311 sec (120.405 average)
#
#  ****** Running generation 12 ******
#
# Population's average fitness: -9547.85556 stdev: 1279.96266
# Best fitness: -9011.00000 - size: (4, 373) - species 1 - id 671
# Species length: 1 totaling 60 individuals
# Species no improv: {1: 9}
# Average adjusted fitness: 0.902
# Spawn amounts: [60]
# Species fitness  : [0.90188445527464778]
# Mean genetic distance 1.52625874093, std dev 0.160148957016
# Total extinctions: 0
# Generation time: 103.388 sec (118.516 average)
#
#  ****** Running generation 13 ******
#
# Population's average fitness: -10027.55556 stdev: 1731.22354
# Best fitness: -9011.00000 - size: (4, 373) - species 1 - id 671
# Species length: 1 totaling 60 individuals
# Species no improv: {1: 10}
# Average adjusted fitness: 0.833
# Spawn amounts: [60]
# Species fitness  : [0.83342436821790122]
# Mean genetic distance 1.51759437238, std dev 0.199777805087
# Total extinctions: 0
# Generation time: 114.872 sec (116.780 average)
# Saving checkpoint to neat-checkpoint-13
#
#  ****** Running generation 14 ******
#
# Population's average fitness: -9888.97222 stdev: 1568.25456
# Best fitness: -9011.00000 - size: (4, 373) - species 1 - id 671
# Species length: 1 totaling 60 individuals
# Species no improv: {1: 11}
# Average adjusted fitness: 0.836
# Spawn amounts: [60]
# Species fitness  : [0.83627048755724076]
# Mean genetic distance 1.59410212239, std dev 0.20494589066
# Total extinctions: 0
# Generation time: 111.670 sec (114.860 average)
#
#  ****** Running generation 15 ******
#
# Population's average fitness: -9421.82222 stdev: 1018.91934
# Best fitness: -9011.00000 - size: (4, 373) - species 1 - id 671
# Species length: 1 totaling 60 individuals
# Species no improv: {1: 12}
# Average adjusted fitness: 0.892
# Spawn amounts: [60]
# Species fitness  : [0.89221036674246379]
# Mean genetic distance 1.43139119572, std dev 0.145036857171
# Total extinctions: 0
# Generation time: 107.675 sec (113.480 average)
#
#  ****** Running generation 16 ******
#
# Population's average fitness: -9592.00556 stdev: 1270.82283
# Best fitness: -9011.00000 - size: (4, 373) - species 1 - id 756
# Species length: 1 totaling 60 individuals
# Species no improv: {1: 13}
# Average adjusted fitness: 0.903
# Spawn amounts: [60]
# Species fitness  : [0.90347141459452507]
# Mean genetic distance 1.58081015763, std dev 0.251787646388
# Total extinctions: 0
# Generation time: 109.181 sec (111.609 average)
# Saving checkpoint to neat-checkpoint-16
#
#  ****** Running generation 17 ******
#
# Population's average fitness: -9711.35556 stdev: 1338.25734
# Best fitness: -9011.00000 - size: (7, 362) - species 1 - id 992
# Species length: 1 totaling 60 individuals
# Species no improv: {1: 14}
# Average adjusted fitness: 0.861
# Spawn amounts: [60]
# Species fitness  : [0.86104975420496876]
# Mean genetic distance 1.59498263991, std dev 0.170987372946
# Total extinctions: 0
# Generation time: 112.978 sec (111.503 average)
#
#  ****** Running generation 18 ******
#
# Population's average fitness: -9714.81111 stdev: 1354.29261
# Best fitness: -7355.66667 - size: (5, 357) - species 1 - id 1074
# Species length: 1 totaling 60 individuals
# Species no improv: {1: 0}
# Average adjusted fitness: 0.652
# Spawn amounts: [60]
# Species fitness  : [0.65176966476415421]
# Mean genetic distance 1.52071456074, std dev 0.232064353281
# Total extinctions: 0
# Generation time: 119.184 sec (113.958 average)
#
#  ****** Running generation 19 ******
#
# Population's average fitness: -9707.45000 stdev: 1466.64235
# Best fitness: -7355.66667 - size: (5, 357) - species 1 - id 1074
# Species length: 1 totaling 60 individuals
# Species no improv: {1: 1}
# Average adjusted fitness: 0.686
# Spawn amounts: [60]
# Species fitness  : [0.68616387171389148]
# Mean genetic distance 1.70264289674, std dev 0.183109644881
# Total extinctions: 0
# Generation time: 120.700 sec (113.005 average)
# Saving checkpoint to neat-checkpoint-19
#
#  ****** Running generation 20 ******
#
# Population's average fitness: -9672.11111 stdev: 1511.32231
# Best fitness: -6528.00000 - size: (5, 352) - species 1 - id 1218
# Species length: 1 totaling 60 individuals
# Species no improv: {1: 0}
# Average adjusted fitness: 0.650
# Spawn amounts: [60]
# Species fitness  : [0.65047308480940713]
# Mean genetic distance 1.72504198792, std dev 0.146870531883
# Total extinctions: 0
# Generation time: 118.228 sec (112.819 average)
#
#  ****** Running generation 21 ******
#
# Population's average fitness: -10114.29444 stdev: 1818.41824
# Best fitness: -6528.00000 - size: (5, 352) - species 1 - id 1218
# Species length: 1 totaling 60 individuals
# Species no improv: {1: 1}
# Average adjusted fitness: 0.528
# Spawn amounts: [60]
# Species fitness  : [0.52818123346343349]
# Mean genetic distance 1.48592560587, std dev 0.204609730989
# Total extinctions: 0
# Generation time: 130.827 sec (114.870 average)
#
#  ****** Running generation 22 ******
#
# Population's average fitness: -9607.10556 stdev: 1555.92499
# Best fitness: -6528.00000 - size: (5, 353) - species 1 - id 1292
# Species length: 1 totaling 60 individuals
# Species no improv: {1: 2}
# Average adjusted fitness: 0.596
# Spawn amounts: [60]
# Species fitness  : [0.59628876943024067]
# Mean genetic distance 1.53590350261, std dev 0.219232363983
# Total extinctions: 0
# Generation time: 97.949 sec (114.326 average)
# Saving checkpoint to neat-checkpoint-22
#
#  ****** Running generation 23 ******
#
# Population's average fitness: -10187.97222 stdev: 1860.54922
# Best fitness: -6528.00000 - size: (5, 350) - species 1 - id 1319
# Species length: 1 totaling 60 individuals
# Species no improv: {1: 3}
# Average adjusted fitness: 0.595
# Spawn amounts: [60]
# Species fitness  : [0.59462760589726538]
# Mean genetic distance 1.56349244195, std dev 0.312455978139
# Total extinctions: 0
# Generation time: 134.003 sec (116.240 average)
#
#  ****** Running generation 24 ******
#
# Population's average fitness: -10437.87222 stdev: 2077.74796
# Best fitness: -6528.00000 - size: (3, 342) - species 1 - id 1423
# Species length: 1 totaling 60 individuals
# Species no improv: {1: 4}
# Average adjusted fitness: 0.537
# Spawn amounts: [60]
# Species fitness  : [0.53670840245411722]
# Mean genetic distance 1.46263023581, std dev 0.183955597945
# Total extinctions: 0
# Generation time: 129.316 sec (118.004 average)
#
#  ****** Running generation 25 ******
#
# Population's average fitness: -10486.85000 stdev: 1768.22716
# Best fitness: -6528.00000 - size: (3, 342) - species 1 - id 1423
# Species length: 1 totaling 60 individuals
# Species no improv: {1: 5}
# Average adjusted fitness: 0.485
# Spawn amounts: [60]
# Species fitness  : [0.48530660888407334]
# Mean genetic distance 1.53778878275, std dev 0.184956947049
# Total extinctions: 0
# Generation time: 133.678 sec (120.604 average)
# Saving checkpoint to neat-checkpoint-25
#
#  ****** Running generation 26 ******
#
# Population's average fitness: -10087.10556 stdev: 1874.36815
# Best fitness: -6528.00000 - size: (4, 338) - species 1 - id 1539
# Species length: 1 totaling 60 individuals
# Species no improv: {1: 6}
# Average adjusted fitness: 0.581
# Spawn amounts: [60]
# Species fitness  : [0.58138019812331732]
# Mean genetic distance 1.56534108327, std dev 0.282494695783
# Total extinctions: 0
# Generation time: 117.040 sec (121.390 average)
#
#  ****** Running generation 27 ******
#
# Population's average fitness: -9706.33333 stdev: 1771.58748
# Best fitness: -6528.00000 - size: (4, 338) - species 1 - id 1539
# Species length: 1 totaling 60 individuals
# Species no improv: {1: 7}
# Average adjusted fitness: 0.647
# Spawn amounts: [60]
# Species fitness  : [0.64736121897999155]
# Mean genetic distance 1.71504019514, std dev 0.263034457702
# Total extinctions: 0
# Generation time: 114.832 sec (121.576 average)
#
#  ****** Running generation 28 ******
#
# Population's average fitness: -9730.18333 stdev: 1623.76925
# Best fitness: -6528.00000 - size: (4, 338) - species 1 - id 1539
# Species length: 1 totaling 60 individuals
# Species no improv: {1: 8}
# Average adjusted fitness: 0.637
# Spawn amounts: [60]
# Species fitness  : [0.63736552036540728]
# Mean genetic distance 1.49962372227, std dev 0.308403117155
# Total extinctions: 0
# Generation time: 120.301 sec (121.687 average)
# Saving checkpoint to neat-checkpoint-28
#
#  ****** Running generation 29 ******
#
# Population's average fitness: -9512.34444 stdev: 1354.88500
# Best fitness: -6528.00000 - size: (4, 338) - species 1 - id 1539
# Species length: 1 totaling 60 individuals
# Species no improv: {1: 9}
# Average adjusted fitness: 0.614
# Spawn amounts: [60]
# Species fitness  : [0.61382706464228221]
# Mean genetic distance 1.50904943928, std dev 0.232496783173
# Total extinctions: 0
# Generation time: 101.530 sec (119.770 average)
#
#  ****** Running generation 30 ******
#
# Population's average fitness: -9773.77778 stdev: 1497.19870
# Best fitness: -6528.00000 - size: (3, 342) - species 1 - id 1423
# Species length: 1 totaling 60 individuals
# Species no improv: {1: 10}
# Average adjusted fitness: 0.569
# Spawn amounts: [60]
# Species fitness  : [0.56882020398825073]
# Mean genetic distance 1.65381471138, std dev 0.282847542269
# Total extinctions: 0
# Generation time: 124.952 sec (120.443 average)
#
#  ****** Running generation 31 ******
#
# Population's average fitness: -9604.33889 stdev: 1463.95771
# Best fitness: -6528.00000 - size: (3, 342) - species 1 - id 1423
# Species length: 1 totaling 60 individuals
# Species no improv: {1: 11}
# Average adjusted fitness: 0.646
# Spawn amounts: [60]
# Species fitness  : [0.645814304537488]
# Mean genetic distance 1.74621640701, std dev 0.322737414943
# Total extinctions: 0
# Generation time: 107.358 sec (118.096 average)
# Saving checkpoint to neat-checkpoint-31
#
#  ****** Running generation 32 ******
#
# Population's average fitness: -9569.10000 stdev: 1406.83687
# Best fitness: -6528.00000 - size: (4, 338) - species 1 - id 1539
# Species length: 1 totaling 60 individuals
# Species no improv: {1: 12}
# Average adjusted fitness: 0.503
# Spawn amounts: [60]
# Species fitness  : [0.50297995205927204]
# Mean genetic distance 1.48274683685, std dev 0.337228129651
# Total extinctions: 0
# Generation time: 104.940 sec (118.795 average)
#
#  ****** Running generation 33 ******
#
# Population's average fitness: -9611.92778 stdev: 1403.74163
# Best fitness: -6528.00000 - size: (3, 342) - species 1 - id 1423
# Species length: 1 totaling 60 individuals
# Species no improv: {1: 13}
# Average adjusted fitness: 0.527
# Spawn amounts: [60]
# Species fitness  : [0.52666615505303715]
# Mean genetic distance 1.55088788801, std dev 0.407797924333
# Total extinctions: 0
# Generation time: 96.261 sec (115.021 average)
#
#  ****** Running generation 34 ******
#
# Population's average fitness: -9919.88333 stdev: 1594.35412
# Best fitness: -6528.00000 - size: (3, 342) - species 1 - id 1423
# Species length: 1 totaling 60 individuals
# Species no improv: {1: 14}
# Average adjusted fitness: 0.580
# Spawn amounts: [60]
# Species fitness  : [0.57983111735073112]
# Mean genetic distance 1.30646369527, std dev 0.386628282666
# Total extinctions: 0
# Generation time: 119.235 sec (114.013 average)
# Saving checkpoint to neat-checkpoint-34
#
#  ****** Running generation 35 ******
#
# Population's average fitness: -9798.53333 stdev: 1545.54591
# Best fitness: -6528.00000 - size: (4, 338) - species 1 - id 1539
# Species length: 1 totaling 60 individuals
# Species no improv: {1: 15}
# Average adjusted fitness: 0.583
# Spawn amounts: [60]
# Species fitness  : [0.58299970249479371]
# Mean genetic distance 1.36794090124, std dev 0.198681262162
# Total extinctions: 0
# Generation time: 125.317 sec (113.177 average)
#
#  ****** Running generation 36 ******
#
# Population's average fitness: -9531.59444 stdev: 1642.99620
# Best fitness: -6528.00000 - size: (3, 342) - species 1 - id 1423
# Species length: 1 totaling 60 individuals
# Species no improv: {1: 16}
# Average adjusted fitness: 0.699
# Spawn amounts: [60]
# Species fitness  : [0.69928972690360969]
# Mean genetic distance 1.44009760072, std dev 0.275695390054
# Total extinctions: 0
# Generation time: 90.911 sec (110.564 average)
#
#  ****** Running generation 37 ******
#
# Population's average fitness: -9968.30000 stdev: 1562.66319
# Best fitness: -6528.00000 - size: (3, 342) - species 1 - id 1423
# Species length: 1 totaling 60 individuals
# Species no improv: {1: 17}
# Average adjusted fitness: 0.470
# Spawn amounts: [60]
# Species fitness  : [0.47004364569961493]
# Mean genetic distance 1.46928240859, std dev 0.21335392274
# Total extinctions: 0
# Generation time: 127.844 sec (111.865 average)
# Saving checkpoint to neat-checkpoint-37
#
#  ****** Running generation 38 ******
#
# Population's average fitness: -9877.76667 stdev: 1769.82376
# Best fitness: -7355.66667 - size: (3, 342) - species 1 - id 1423
# Species length: 1 totaling 60 individuals
# Species no improv: {1: 18}
# Average adjusted fitness: 0.717
# Spawn amounts: [60]
# Species fitness  : [0.71729562098341071]
# Mean genetic distance 1.70390321342, std dev 0.272294194823
# Total extinctions: 0
# Generation time: 119.516 sec (111.786 average)
#
#  ****** Running generation 39 ******
#
# Population's average fitness: -10209.05000 stdev: 1834.11536
# Best fitness: -6528.00000 - size: (3, 342) - species 1 - id 1423
# Species length: 1 totaling 60 individuals
# Species no improv: {1: 19}
# Average adjusted fitness: 0.588
# Spawn amounts: [60]
# Species fitness  : [0.58755742296918756]
# Mean genetic distance 1.92287140075, std dev 0.227426739549
# Total extinctions: 0
# Generation time: 122.789 sec (113.912 average)
#
#  ****** Running generation 40 ******
#
# Population's average fitness: -9784.31667 stdev: 1440.90501
# Best fitness: -6528.00000 - size: (3, 342) - species 1 - id 1423
# Species length: 1 totaling 60 individuals
# Species no improv: {1: 20}
#
# Species 1 with 60 members is stagnated: removing it
# All species extinct.
# ---------------------------------------------------------------------------
# CompleteExtinctionException               Traceback (most recent call last)
# <ipython-input-8-39fbbe22f9ba> in <module>()
#       1 # Run evolution
# ----> 2 winner = p.run(evaluator.evaluate, 100)
#
# /home/etoestja/venv/lib/python2.7/site-packages/neat/population.pyc in run(self, fitness_function, n)
#      90                                                                    self.config.pop_size)
#      91                 else:
# ---> 92                     raise CompleteExtinctionException()
#      93
#      94             # Update species age.
#
# CompleteExtinctionException:

# %% [markdown]
# # Print results

# %%
# Display the winning genome.
#print('\nBest genome:\n{!s}'.format(winner))
winner = p.best_genome
# Show output of the most fit genome against training data.
winner_network = neat.nn.FeedForwardNetwork.create(winner, config)
visualize.draw_net(config, winner, False)
visualize.plot_stats(stats, ylog = False, view = False)
visualize.plot_species(stats, view = False)

#p = neat.Checkpointer.restore_checkpoint('neat-checkpoint-4')
#p.run(eval_genomes, 10)

# %% [markdown]
# # Evaluate from checkpoint & send to OpenAI

# %%
p = neat.Checkpointer.restore_checkpoint('neat-checkpoint-76')
p.run(evaluator.evaluate, 1)
winner = p.best_genome

# %%
env_eval = gym.make(game)
monitor_path = '/tmp/' + game + '-eval'
env_eval = wrappers.Monitor(env_eval, monitor_path)
def evaluate_with_video(game, network):
    for i_episode in range(100):
        observation = env_eval.reset()
        total_reward = 0
        t = 0
        while True:
            env_eval.render()
            action = predict_action(observation, network)
            observation, reward, done, info = env_eval.step(action)
            total_reward += reward
            t += 1
            if done:
                print("Episode finished after {0} timesteps reward = {1}".format(t+1, total_reward))
                break

# %%
evaluate_with_video(game, winner_network)

# %%
env_eval.close()

# %%
gym.upload(monitor_path, api_key='sk_ciz2F0csRzCkpESayoRuug')
